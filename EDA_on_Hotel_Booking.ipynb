# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushaErugadhindla/Hotel_Booking/blob/main/EDA_on_Hotel_Booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Hotel Bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
list(df.columns)
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.dtypes.values
# Out:
# array([dtype('O'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('O'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('float64'), dtype('int64'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('O'), dtype('float64'), dtype('float64'),
#        dtype('int64'), dtype('O'), dtype('float64'), dtype('int64'),
#        dtype('int64'), dtype('O'), dtype('O')], dtype=object)

# %%
df.dtypes.tolist()
# Out:
# [dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O')]

# %%
[dtype.name for dtype in df.dtypes]
# Out:
# ['object',
#  'int64',
#  'int64',
#  'int64',
#  'object',
#  'int64',
#  'int64',
#  'int64',
#  'int64',
#  'int64',
#  'float64',
#  'int64',
#  'object',
#  'object',
#  'object',
#  'object',
#  'int64',
#  'int64',
#  'int64',
#  'object',
#  'object',
#  'int64',
#  'object',
#  'float64',
#  'float64',
#  'int64',
#  'object',
#  'float64',
#  'int64',
#  'int64',
#  'object',
#  'object']

# %%
#Line-seperating string
data_type_string = "\n".join([dtype.name for dtype in df.dtypes])
print(data_type_string)
# Out:
# object
# int64
# int64
# int64
# object
# int64
# int64
# int64
# int64
# int64
# float64
# int64
# object
# object
# object
# object
# int64
# int64
# int64
# object
# object
# int64
# object
# float64
# float64
# int64
# object
# float64
# int64
# int64
# object
# object

# %%
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
df.describe(include='object').T
# Out:
#                           count unique         top    freq
# hotel                    119390      2  City Hotel   79330
# arrival_date_month       119390     12      August   13877
# meal                     119390      5          BB   92310
# country                  118902    177         PRT   48590
# market_segment           119390      8   Online TA   56477
# distribution_channel     119390      5       TA/TO   97870
# reserved_room_type       119390     10           A   85994
# assigned_room_type       119390     12           A   74053
# deposit_type             119390      3  No Deposit  104641
# customer_type            119390      4   Transient   89613
# reservation_status       119390      3   Check-Out   75166
# reservation_status_date  119390    926  2015-10-21    1461

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
#deleting company column
df.drop(columns=['company'],inplace=True)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
#filling agent column with median value
df['agent'].fillna(df['agent'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# days_in_waiting_list                0
# ...

# %%
#filling children column with mean value
df['children'].fillna(df['children'].mean(),inplace=True)

# %%
#filling country with mode value
df['country'].fillna(df['country'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
#checking duplicated values
df.duplicated().sum()
# Out:
# np.int64(32020)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
#changing reservation_status_date into date and time
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
#converting children and agent column into int datatype
df['children']=df['children'].astype('int64')
df['agent']=df['agent'].astype('int64')

# %%
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                   int64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %% [markdown]
# # Exploring Data

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 20 numerical features : ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status_date']
#
# We have 11 categorical features : ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status']

# %%
# proportion of count data on categorical columns
for col in categorical_features:
    print(df[col].value_counts(normalize=True) * 100)
    print('---------------------------')
# Out:
# hotel
# City Hotel      61.149136
# Resort Hotel    38.850864
# Name: proportion, dtype: float64
# ---------------------------
# arrival_date_month
# August       12.884285
# July         11.508527
# May           9.561634
# April         9.047728
# June          8.887490
# March         8.595628
# October       7.934073
# September     7.655946
# February      6.971501
# December      5.869292
# November      5.714776
# January       5.369120
# Name: proportion, dtype: float64
# ---------------------------
# meal
# BB           77.778414
# SC           10.851551
# HB           10.397161
# Undefined     0.560833
# FB            0.412041
# Name: proportion, dtype: float64
# ---------------------------
# country
# PRT    31.912556
# GBR    11.940025
# FRA    10.114456
# ESP     8.300332
# DEU     6.165732
#          ...
# MRT     0.001145
# KIR     0.001145
# SDN     0.001145
# ATF     0.001145
# SLE     0.001145
# Name: proportion, Length: 177, dtype: float64
# ...

# %% [markdown]
# **Univariate Analysis**

# %%
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                   int64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
df.head(1)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
#
#    booking_changes  deposit_type agent days_in_waiting_list customer_type  \
# 0                3    No Deposit    14                    0     Transient
#
#    adr  required_car_parking_spaces  total_of_special_requests  \
# 0  0.0                            0                          0
#
#    reservation_status reservation_status_date
# 0           Check-Out              2015-07-01
#
# [1 rows x 31 columns]

# %% [markdown]
# ***Numerical Features***

# %%
import math

plt.figure(figsize=(20, 25)) # Increased figure size to accommodate more plots
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

# The original loop started from index 1, skipping the first numerical feature.
# It attempts to plot len(numeric_features) - 1 features.
num_features_to_plot = len(numeric_features) - 1

# Define the number of columns and dynamically calculate rows
ncols = 4
nrows = math.ceil(num_features_to_plot / ncols)

for plot_idx, i in enumerate(range(1, len(numeric_features))):
    # plot_idx starts from 0, so add 1 for subplot index
    plt.subplot(nrows, ncols, plot_idx + 1)
    sns.kdeplot(x=df[numeric_features[i]], color='red')
    plt.xlabel(numeric_features[i])
plt.tight_layout()

# %%
import math

num_features = len(numeric_features)
rows = math.ceil(num_features / 2)  # Calculate number of rows

plt.figure(figsize=(10, 3 * rows))  # Adjust figure size based on the number of rows
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

for i in range(num_features):
    plt.subplot(rows, 2, i+1)  # 2 columns for each row
    sns.kdeplot(x=df[numeric_features[i]], color='red')
    plt.xlabel(numeric_features[i])
plt.tight_layout()

# %% [markdown]
# ***Categorical Features***

# %%
import math

ncols = 3  # Set the number of columns for the subplots
nrows = math.ceil(len(categorical_features) / ncols) # Calculate the number of rows needed

# Adjust figure size dynamically based on the number of rows
plt.figure(figsize=(15, 4 * nrows))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(categorical_features)):
    plt.subplot(nrows, ncols, i+1)
    sns.countplot(y=df[categorical_features[i]], palette='viridis') # Using countplot for categorical features
    plt.title(f'Distribution of {categorical_features[i]}', fontsize=10) # Add a title for each subplot
    plt.xlabel('Count') # Label for the count axis
    plt.ylabel('') # Remove y-axis label as it's redundant with the title

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust tight_layout to prevent suptitle overlap
plt.show()

# %%
discrete_features=[feature for feature in numeric_features if len(df[feature].unique())<=25]

continuous_features=[feature for feature in numeric_features if len(df[feature].unique()) > 25]

print('We have {} discrete features : {}'.format(len(discrete_features), discrete_features))
print('\nWe have {} continuous_features : {}'.format(len(continuous_features), continuous_features))
# Out:
# We have 11 discrete features : ['is_canceled', 'arrival_date_year', 'stays_in_weekend_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests']
#
# We have 9 continuous_features : ['lead_time', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_week_nights', 'previous_bookings_not_canceled', 'agent', 'days_in_waiting_list', 'adr', 'reservation_status_date']

# %% [markdown]
# # Check multicollinearity for cateegorical features

# %%
from pandas.core.arrays import categorical
from scipy.stats import chi2_contingency
chi2_test=[]
for feature in categorical_features:
  if chi2_contingency(pd.crosstab(df['is_canceled'],df[feature]))[1]<0.05:
    chi2_test.append('reject Null Hypothesis')
  else:
    chi2_test.append('fail to reject Null Hypothesis')
result=pd.DataFrame(data=[categorical_features,chi2_test]).T
result.columns=['feature','Chi2_test']
result
# Out:
#                  feature               Chi2_test
# 0                  hotel  reject Null Hypothesis
# 1     arrival_date_month  reject Null Hypothesis
# 2                   meal  reject Null Hypothesis
# 3                country  reject Null Hypothesis
# 4         market_segment  reject Null Hypothesis
# 5   distribution_channel  reject Null Hypothesis
# 6     reserved_room_type  reject Null Hypothesis
# 7     assigned_room_type  reject Null Hypothesis
# 8           deposit_type  reject Null Hypothesis
# 9          customer_type  reject Null Hypothesis
# 10    reservation_status  reject Null Hypothesis

# %%
clr1 = ['#1E90FF', '#DC143C']
num_rows = 5 # Define the number of rows in the subplot grid

# Calculate the number of columns based on the number of features
num_cols = math.ceil(len(discrete_features) / num_rows)

# Adjust the figure size to accommodate all the subplots
fig_width = 15
fig_height = 5 * num_rows  # Adjust height to fit all rows nicely

fig, ax = plt.subplots(num_rows, 2, figsize=(fig_width, fig_height))
fig.suptitle('Distribution of discrete_features By is_canceled', color='#3C3744',
             fontsize=20, fontweight='bold', ha='center')

for i, col in enumerate(discrete_features):
    if i < num_rows * 2:  # Create subplots only if within the range of available space
        row_index = i % num_rows
        col_index = i // num_rows

        sns.boxplot(data=df, x='is_canceled', y=col,  palette=clr1, ax=ax[row_index, 0])
        ax[row_index, 0].set_title(f'Boxplot of {col}', fontsize=12)

        sns.histplot(data=df, x=col, hue='is_canceled', bins=20, kde=True,
                     multiple='stack', palette=clr1, ax=ax[row_index, 1])
        ax[row_index, 1].set_title(f'Histogram of {col}', fontsize=14)
    else:
        break  # Stop creating subplots if we run out of features

# Hide unused subplots
for i in range(len(discrete_features), num_rows * 2):
    ax[i // 2, i % 2].axis('on')

fig.tight_layout()
fig.subplots_adjust(top=0.92)
# plt.savefig('images/multivariate_num.png')

# %%
clr1=['#1E90EF','#DC143C']
num_features = len(continuous_features) # Get the number of continuous features
num_rows = num_features # Each continuous feature will get its own row for its two plots
fig,ax=plt.subplots(num_rows, 2, figsize=(10, 4 * num_rows)) # Dynamically set rows and adjust figure size
fig.suptitle('Distribution of continuous_features By is_canceled',color='#3C3744',fontsize=20,fontweight='bold',ha='center')
for i, col in enumerate(continuous_features):
        sns.boxplot(data=df, x='is_canceled', y=col,  palette=clr1, ax=ax[i, 0])
        ax[i, 0].set_title(f'Boxplot of {col}', fontsize=12)
        sns.histplot(data=df, x=col, hue='is_canceled', bins=20, kde=True,
                     multiple='stack', palette=clr1, ax=ax[i, 1])
        ax[i, 1].set_title(f'Histogram of {col}', fontsize=14)
fig.tight_layout()
fig.subplots_adjust(top=0.92)

# %% [markdown]
# # Visualize the Target Feature

# %%
df['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    63346
# 1    24024
# Name: count, dtype: int64

# %%
df.is_canceled.value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    72.503148
# 1    27.496852
# Name: proportion, dtype: float64

# %%
percentage=df.is_canceled.value_counts(normalize=True)*100
label=['No','Yes']
#plot pie chart with ploty library
fig,ax=plt.subplots(figsize=(15,8))
explode=(0,0.1)
colors=['#1188ff','#e63a2a']
ax.pie(percentage,labels=label,startangle=90,autopct='%1.2f%%',explode=explode,shadow=True,colors=colors)
plt.show()

# %% [markdown]
# # Cancellation Analysis by Key Features

# %%
# Set style
sns.set(style="whitegrid")

# Create subplots (2 rows, 3 columns)
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Hotel type vs cancellation rate
sns.barplot(x="hotel", y="is_canceled", data=df,
            estimator=lambda x: sum(x)/len(x), ax=axes[0,0])
axes[0,0].set_title("Cancellation Rate by Hotel Type")
axes[0,0].set_ylabel("Rate")

# 2. Lead time distribution
sns.boxplot(x="is_canceled", y="lead_time", data=df, ax=axes[0,1])
axes[0,1].set_title("Lead Time vs Cancellation")
axes[0,1].set_xlabel("Is Canceled (0=No, 1=Yes)")
axes[0,1].set_ylabel("Lead Time")

# 3. Arrival month vs cancellation rate
sns.barplot(x="arrival_date_month", y="is_canceled", data=df,
            estimator=lambda x: sum(x)/len(x),
            order=["January","February","March","April","May","June",
                   "July","August","September","October","November","December"],
            ax=axes[0,2])
axes[0,2].set_title("Cancellation Rate by Month")
axes[0,2].set_ylabel("Rate")
axes[0,2].tick_params(axis='x', rotation=45)
# 4. Deposit type vs cancellation rate
sns.barplot(x="deposit_type", y="is_canceled", data=df,
            estimator=lambda x: sum(x)/len(x), ax=axes[1,0])
axes[1,0].set_title("Cancellation Rate by Deposit Type")
axes[1,0].set_ylabel("Rate")

# 5. Market segment vs cancellation rate
sns.barplot(x="market_segment", y="is_canceled", data=df,
            estimator=lambda x: sum(x)/len(x), ax=axes[1,1])
axes[1,1].set_title("Cancellation Rate by Market Segment")
axes[1,1].set_ylabel("Rate")
axes[1,1].tick_params(axis='x', rotation=45)

# Hide the last empty subplot (bottom-right)
fig.delaxes(axes[1,2])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Does hotel has any impact on is_canceled?**

# %%
#group by hotel and their count of is_canceled
df.groupby('hotel').is_canceled.value_counts(normalize=True).to_frame()*100
# Out:
#                           proportion
# hotel        is_canceled
# City Hotel   0             69.960319
#              1             30.039681
# Resort Hotel 0             76.505421
#              1             23.494579

# %%
# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(20, 7))

# Plot the countplot
sns.countplot(x="hotel", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax)
plt.title("hotel vs is_canceled", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Hotel", weight="bold", fontsize=16)
plt.legend(title="Default Status", fancybox=True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Calculate percentages and annotate on top of each bar
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# The analysis indicates that the type of hotel influences the likelihood of booking cancellations.
# City Hotels generally show higher cancellation rates compared to Resort Hotels

# %% [markdown]
# # **Does lead_time make impact on is_canceled?**

# %%
#group by hotel and their count of is_canceled
df.groupby('lead_time').is_canceled.value_counts(normalize=True).to_frame()*100
# Out:
#                        proportion
# lead_time is_canceled
# 0         0             94.087102
#           1              5.912898
# 1         0             93.339558
#           1              6.660442
# 2         0             90.545455
# ...                           ...
# 622       1            100.000000
# 626       1            100.000000
# 629       1            100.000000
# 709       0            100.000000
# 737       0            100.000000
#
# [887 rows x 1 columns]

# %%
# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(20, 7))

# Plot the countplot
sns.countplot(x="lead_time", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax)
plt.title("lead_time vs is_canceled", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("lead_time", weight="bold", fontsize=16)
plt.legend(title="Default Status", fancybox=True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Calculate percentages and annotate on top of each bar
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# Lead time demonstrates a strong positive relationship with booking cancellation.
# Bookings made far in advance exhibit a significantly higher probability of cancellation.

# %% [markdown]
# # Does deposit_type make impact on is_cancelled?

# %%
#group by hotel and their count of is_canceled
print(df.groupby('deposit_type').is_canceled.value_counts(normalize=True).to_frame()*100)
# Out:
#                           proportion
# deposit_type is_canceled
# No Deposit   0             73.308205
#              1             26.691795
# Non Refund   1             94.701349
#              0              5.298651
# Refundable   0             75.700935
#              1             24.299065

# %%
fig, ax = plt.subplots(figsize=(12,6))

# Plot countplot: deposit type vs cancellation
sns.countplot(x="deposit_type", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax)

plt.title("Deposit Type vs Cancellation", fontsize=18, weight="bold")
plt.ylabel("Count")
plt.xlabel("Deposit Type")
plt.legend(title="Cancellation Status")

# Annotate percentages
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%',
                (p.get_x() + p.get_width()/2., height),
                ha='center', va='center', fontsize=10, color='black',
                xytext=(0,5), textcoords='offset points')

plt.show()

# %% [markdown]
# Bookings with no deposit record the highest cancellation rates, while non-refundable deposits greatly reduce the likelihood of cancellation.

# %% [markdown]
# # Does market_segment make an impact on is_cancelled?

# %%
# Group by market segment and cancellation status
print(df.groupby('market_segment').is_canceled.value_counts(normalize=True).to_frame()*100)
# Out:
#                             proportion
# market_segment is_canceled
# Aviation       0             80.176211
#                1             19.823789
# Complementary  0             87.464387
#                1             12.535613
# Corporate      0             87.862922
#                1             12.137078
# Direct         0             85.277166
#                1             14.722834
# Groups         0             72.975709
#                1             27.024291
# Offline TA/TO  0             85.150511
#                1             14.849489
# Online TA      0             64.650379
#                1             35.349621
# Undefined      1            100.000000

# %%
fig, ax = plt.subplots(figsize=(14,6))

# Plot countplot: market segment vs cancellation
sns.countplot(x="market_segment", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax)

plt.title("Market Segment vs Cancellation", fontsize=18, weight="bold")
plt.ylabel("Count")
plt.xlabel("Market Segment")
plt.legend(title="Cancellation Status")

# Annotate percentages
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%',
                (p.get_x() + p.get_width()/2., height),
                ha='center', va='center', fontsize=10, color='black',
                xytext=(0,5), textcoords='offset points')

# Rotate x-axis labels for readability
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Bookings with no deposit record the highest cancellation rates, while non-refundable deposits greatly reduce the likelihood of cancellation.

# %% [markdown]
# # Does Arrival Month make impact on is_cancelled?

# %%
# Group by arrival month and cancellation status
print(df.groupby('arrival_date_month').is_canceled.value_counts(normalize=True).to_frame()*100)
# Out:
#                                 proportion
# arrival_date_month is_canceled
# April              0             69.538267
#                    1             30.461733
# August             0             67.815581
#                    1             32.184419
# December           0             73.127925
#                    1             26.872075
# February           0             76.769003
#                    1             23.230997
# January            0             77.872522
#                    1             22.127478
# July               0             68.194928
#                    1             31.805072
# June               0             69.684482
#                    1             30.315518
# March              0             75.632490
#                    1             24.367510
# May                0             70.768494
#                    1             29.231506
# November           0             78.890447
#                    1             21.109553
# ...

# %%
fig, ax = plt.subplots(figsize=(14,6))

# Plot countplot: arrival month vs cancellation
sns.countplot(x="arrival_date_month", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax,
              order=["January","February","March","April","May","June",
                     "July","August","September","October","November","December"])

plt.title("Arrival Month vs Cancellation", fontsize=18, weight="bold")
plt.ylabel("Count")
plt.xlabel("Arrival Month")
plt.legend(title="Cancellation Status")

# Annotate percentages
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%',
                (p.get_x() + p.get_width()/2., height),
                ha='center', va='center', fontsize=10, color='black',
                xytext=(0,5), textcoords='offset points')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The arrival month demonstrates noticeable patterns in cancellation behavior.
# Peak-season months tend to experience higher cancellation rates.Off-season months usually show lower cancellation rates.

# %% [markdown]
# # Does customer_type make impact on is_cancelled?

# %%
# Group by customer type and cancellation status
print(df.groupby('customer_type').is_canceled.value_counts(normalize=True).to_frame()*100)
# Out:
#                              proportion
# customer_type   is_canceled
# Contract        0             83.689073
#                 1             16.310927
# Group           0             90.073529
#                 1              9.926471
# Transient       0             69.888006
#                 1             30.111994
# Transient-Party 0             84.751259
#                 1             15.248741

# %%
fig, ax = plt.subplots(figsize=(12,6))

# Plot countplot: customer type vs cancellation
sns.countplot(x="customer_type", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax)

plt.title("Customer Type vs Cancellation", fontsize=18, weight="bold")
plt.ylabel("Count")
plt.xlabel("Customer Type")
plt.legend(title="Cancellation Status")

# Annotate percentages
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%',
                (p.get_x() + p.get_width()/2., height),
                ha='center', va='center', fontsize=10, color='black',
                xytext=(0,5), textcoords='offset points')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Customer type plays a relevant role in determining cancellation likelihood.
# Transient customers, who book individual stays without package deals, tend to exhibit higher cancellation rates due to flexible travel plans.
# Contract customers display significantly lower cancellation behavior, reflecting pre-arranged agreements managed through organizations or long-term partners.
# Group customers also show reduced cancellations, as such bookings are typically planned and coordinated in advance.

# %% [markdown]
# # Does previous cancellation make impact on is_cancelled?

# %%
# Group by previous_cancellations and cancellation status
# This shows the percentage of cancellations for each value of previous_cancellations
print(df.groupby('previous_cancellations').is_canceled.value_counts(normalize=True).to_frame()*100)
# Out:
#                                     proportion
# previous_cancellations is_canceled
# 0                      0             73.297543
#                        1             26.702457
# 1                      1             76.119403
#                        0             23.880597
# 2                      0             69.642857
#                        1             30.357143
# 3                      0             73.770492
#                        1             26.229508
# 4                      0             80.000000
#                        1             20.000000
# 5                      0             89.473684
#                        1             10.526316
# 6                      0             88.235294
#                        1             11.764706
# 11                     0             92.592593
#                        1              7.407407
# 13                     1             75.000000
#                        0             25.000000
# ...

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(14,6))

# Plot countplot: previous_cancellations vs is_canceled
sns.countplot(x="previous_cancellations", hue="is_canceled", data=df, ec="blue", palette="Accent", ax=ax)

# Add title and labels
plt.title("Previous Cancellations vs Current Cancellation", fontsize=18, weight="bold")
plt.ylabel("Count")
plt.xlabel("Number of Previous Cancellations")
plt.legend(title="Cancellation Status")

# Annotate percentages on top of each bar
total_counts = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total_counts) * 100
    ax.annotate(f'{percentage:.2f}%',
                (p.get_x() + p.get_width()/2., height),
                ha='center', va='center', fontsize=10, color='black',
                xytext=(0,5), textcoords='offset points')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The variable representing previous cancellations is a strong behavioral indicator.
# Customers with a history of prior cancellations are more likely to cancel future bookings as well.

# %% [markdown]
# #  Exploratory Data Analysis Report – Hotel Booking Dataset

# %% [markdown]
#  # **Problem:**
#
# A hotel group is facing issues with high booking cancellations. The goal is to analyze the data and understand which factors influence whether a booking is canceled or not.
#
# # **Approach:**
#
# To address this problem, I used a hotel booking dataset containing reservation details for customers staying in City Hotels and Resort Hotels. The dataset includes booking information such as arrival month, customer type, previous cancellations, booking sources, and deposit details.
# The analysis focuses on identifying which variables have a strong impact on the is_canceled feature.
#
# # **Dataset Description:**
#
# The dataset consists of:
#
# hotel – Type of hotel (City Hotel or Resort Hotel).
#
# is_canceled – Indicates whether the booking was canceled (1) or not (0).
#
# lead_time – Number of days between booking date and arrival date.
#
# arrival_date_year – Year of arrival.
#
# arrival_date_month – Month of arrival.
#
# arrival_date_week_number – Week number of arrival date.
#
# arrival_date_day_of_month – Day of the month of arrival.
#
# stays_in_weekend_nights – Number of weekend nights the guest stayed or booked.
#
# stays_in_week_nights – Number of weekday nights the guest stayed or booked.
#
# adults – Number of adults in the booking.
#
# children – Number of children in the booking.
#
# babies – Number of babies in the booking.
#
# meal – Type of meal selected (BB, HB, FB, etc.).
#
# country – Country of origin of the guest.
#
# market_segment – Market segment through which the booking was made (OTA, Direct, Corporate).
#
# distribution_channel – Channel used to confirm the booking.
#
# is_repeated_guest – Identifies if the guest has booked before.
#
# previous_cancellations – Number of previous bookings canceled by the customer.
#
# previous_bookings_not_canceled – Number of previous successful bookings not canceled.
#
# reserved_room_type – Room type reserved at the time of booking.
#
# assigned_room_type – Room type assigned upon arrival.
#
# booking_changes – Number of changes made to the booking.
#
# deposit_type – Deposit requirement (No deposit, Refundable, Non-refundable).
#
# agent – ID of the travel agent who made the booking.
#
# company – ID of the company responsible for the booking.
#
# days_in_waiting_list – Number of days the booking was on the waiting list.
#
# customer_type – Type of customer (Transient, Group, Contract, etc.).
#
# adr – Average daily rate charged per room.
#
# required_car_parking_spaces – Number of car parking spaces required.
#
# total_of_special_requests – Number of special requests made by the guest.
#
# reservation_status – Final reservation status (Canceled, Check-Out, No-Show).
#
# reservation_status_date – Date corresponding to the reservation status.
#
# The dataset contains over 119390 rows and 32 columns.
#
# # **Solution:**
#
# I used NumPy and Pandas to clean and prepare the dataset.
#
# Data Cleaning Steps:
#
# Removed duplicate rows to maintain data quality
#
# Filled missing numerical values with mean and categorical values with mode
#
# Converted arrival date columns into date format
#
# # **Visualizations Used:**
#
# Using Matplotlib and Seaborn, I created:
#
# Count plots
#
# Bar charts
#
# Boxplots
#
# Pie charts
#
# These visuals helped identify the factors that impact cancellations.
#
# Key Insights:
# 1. Arrival Month
#
# Certain months show a higher cancellation rate. Cancellations tend to increase during peak seasons when prices fluctuate and customers change their plans more frequently.
#
# 2. Customer Type
#
# Transient customers show the highest cancellation rates
#
# Contract customers have the lowest cancellation rates
#
# Group customers also cancel less
# This shows that individual travelers are more likely to cancel than corporate or group bookings.
#
# 3. Previous Cancellations
#
# Customers who canceled before are more likely to cancel again.
# This past behavior is a strong indicator of future cancellations.
#
# 4. Lead Time
#
# Long lead times are associated with high cancellations.
# Bookings made months in advance have a higher chance of being changed or canceled.
#
# 5. Deposit Type
#
# No deposit → highest cancellations
#
# Non-refundable deposit → lowest cancellations
# This means financial commitment reduces cancellations.
#
# 6. Market Segment
#
# Online Travel Agent (OTA) bookings have the highest cancellation rate.
# Direct and corporate bookings are more stable.
#
# 7. Hotel Type
#
# City Hotels show more cancellations than Resort Hotels.
#
# # **Challenges:**
#
# Finding and removing duplicates
#
# Handling missing values
#
# Managing outliers in price and lead time
#
# Working with an imbalanced target variable (is_canceled)
#
# # **Technology Used:**
#
# NumPy
#
# Pandas
#
# Matplotlib
#
# Seaborn
